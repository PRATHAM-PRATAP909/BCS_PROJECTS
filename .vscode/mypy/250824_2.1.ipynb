# %%
df=pd.read_csv(r"C:\Users\Pratham\Downloads\Dataset_1 - Sheet1.csv")
print(df.head())
X = df[['House Area', 'Number of rooms']].values   # shape (16, 2)
y = df['Price'].values                    # shape (16,)
# Out:
#    House ID  House Area  Number of rooms  Price
# 0         1        6274                8   2100
# 1         2        6689                5   2200
# 2         3        4276                8   1400
# 3         4        5130                9   1700
# 4         5        6035                6   2000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
